# %% [markdown]
# # Overview
#
# This file describes how to create a system as a graph.
#
# This system is comprised of the following:
#
# - a ZionEx host package
# - a generic rack switch package
# - a generic pod switch package
# - a system that connects those packages in a clos fabric
# - two ZionEx packages connected to 2 rack switches
# - two rack switches connected to 2 pod switches
#
# It also includes a sample use case that describes how host component paths in
# the ZionEx host can be used to create collective communication optimizations.

# %% [markdown]
# # Define a ZionEx Package
#
# This ZionEx class demonstrates how to take the ZionEx block diagram and capture the following:
#
# - the package as a collection of components, links and adjacencies between them using `sys.proto`
#
# ![ZionEx Block Diagram](./meta-zion-ex.png)

# %% [markdown]
# # Create the ZionEx Device
#
# - Create an instance of the ZionEx device
# - Check the ZionEx device by creating a d3graph visualization

# %%
import sys

sys.path.append("..")
sys.path.append("../generated")
from zionex import ZionEx

zionex = ZionEx()
zionex.visualize().jupyter_display()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       3 sys.path.append("..")
# ----> 4 from zionex import ZionEx
#       6 zionex = ZionEx()
#       7 zionex.visualize().jupyter_display()
#
# File ~/github/ajbalogh/chakra_system/src/notes/../zionex.py:10
#       7 from typing import List, Literal, Type, Union
#       9 if __package__ is None or __package__ == "":
# ---> 10     import generated.infra_pb2 as infra
#      11     import builders as bld
#      12 else:
#
# File ~/github/ajbalogh/chakra_system/src/notes/../generated/infra_pb2.py:14
#       9 # @@protoc_insertion_point(imports)
#      11 _sym_db = _symbol_database.Default()
# ---> 14 import et_def_pb2 as et__def__pb2
#      17 DESCRIPTOR = _descriptor_pool.Default().AddSerializedFile(b'\n\x0binfra.proto\x12\x05infra\x1a\x0c\x65t_def.proto\"4\n\x0f\x43ustomComponent\x12!\n\x06memory\x18\x01 \x01(\x0e\x32\x11.infra.MemoryType\"(\n\x03Npu\x12!\n\x06memory\x18\x01 \x01(\x0e\x32\x11.infra.MemoryType\"(\n\x03\x43pu\x12!\n\x06memory\x18\x01 \x01(\x0e\x32\x11.infra.MemoryType\"\x0c\n\nInfiniband\"\n\n\x08\x45thernet\"Z\n\x03Nic\x12#\n\x08\x65thernet\x18\n \x01(\x0b\x32\x0f.infra.EthernetH\x00\x12&\n\tinfinband\x18\x0b \x01(\x0b\x32\x11.infra.InfinibandH\x00\x42\x06\n\x04type\"\x06\n\x04Pcie\"\x08\n\x06NvLink\"N\n\x06Switch\x12\x1b\n\x04pcie\x18\x01 \x01(\x0b\x32\x0b.infra.PcieH\x00\x12\x1f\n\x06nvlink\x18\x02 \x01(\x0b\x32\r.infra.NvLinkH\x00\x42\x06\n\x04type\"\x80\x02\n\tComponent\x12\x0c\n\x04name\x18\x01 \x01(\t\x12\r\n\x05\x63ount\x18\x02 \x01(\r\x12(\n\x06\x63ustom\x18\n \x01(\x0b\x32\x16.infra.CustomComponentH\x00\x12\x19\n\x03\x63pu\x18\x0b \x01(\x0b\x32\n.infra.CpuH\x00\x12\x19\n\x03npu\x18\x0c \x01(\x0b\x32\n.infra.NpuH\x00\x12\x19\n\x03nic\x18\r \x01(\x0b\x32\n.infra.NicH\x00\x12\x1f\n\x06switch\x18\x0e \x01(\x0b\x32\r.infra.SwitchH\x00\x12\x32\n\nattributes\x18\x64 \x03(\x0b\x32\x1e.ChakraProtoMsg.AttributeProtoB\x06\n\x04type\"A\n\tBandwidth\x12\x0e\n\x04gbps\x18\x01 \x01(\rH\x00\x12\r\n\x03gBs\x18\x02 \x01(\rH\x00\x12\r\n\x03gts\x18\x03 \x01(\rH\x00\x42\x06\n\x04type\";\n\x07Latency\x12\x0c\n\x02ms\x18\x01 \x01(\x04H\x00\x12\x0c\n\x02us\x18\x02 \x01(\x04H\x00\x12\x0c\n\x02ns\x18\x03 \x01(\x04H\x00\x42\x06\n\x04type\"\xad\x01\n\x04Link\x12\x0c\n\x04name\x18\x01 \x01(\t\x12\x1d\n\x04type\x18\x02 \x01(\x0e\x32\x0f.infra.LinkType\x12#\n\tbandwidth\x18\n \x01(\x0b\x32\x10.infra.Bandwidth\x12\x1f\n\x07latency\x18\x0b \x01(\x0b\x32\x0e.infra.Latency\x12\x32\n\nattributes\x18\x64 \x03(\x0b\x32\x1e.ChakraProtoMsg.AttributeProto\"Y\n\rComponentLink\x12\n\n\x02\x63\x31\x18\x01 \x01(\t\x12\x10\n\x08\x63\x31_index\x18\x02 \x01(\r\x12\x0c\n\x04link\x18\x03 \x01(\t\x12\n\n\x02\x63\x32\x18\x04 \x01(\t\x12\x10\n\x08\x63\x32_index\x18\x05 \x01(\r\"U\n\x13\x43omponentConnection\x12$\n\x04link\x18\x01 \x01(\x0b\x32\x14.infra.ComponentLinkH\x00\x12\x10\n\x06string\x18\x02 \x01(\tH\x00\x42\x06\n\x04type\"\xa3\x02\n\x06\x44\x65vice\x12\x0c\n\x04name\x18\x01 \x01(\t\x12\x31\n\ncomponents\x18\x03 \x03(\x0b\x32\x1d.infra.Device.ComponentsEntry\x12\'\n\x05links\x18\x04 \x03(\x0b\x32\x18.infra.Device.LinksEntry\x12/\n\x0b\x63onnections\x18\x05 \x03(\x0b\x32\x1a.infra.ComponentConnection\x1a\x43\n\x0f\x43omponentsEntry\x12\x0b\n\x03key\x18\x01 \x01(\t\x12\x1f\n\x05value\x18\x02 \x01(\x0b\x32\x10.infra.Component:\x02\x38\x01\x1a\x39\n\nLinksEntry\x12\x0b\n\x03key\x18\x01 \x01(\t\x12\x1a\n\x05value\x18\x02 \x01(\x0b\x32\x0b.infra.Link:\x02\x38\x01\"\x92\x01\n\nDeviceLink\x12\n\n\x02\x64\x31\x18\x01 \x01(\t\x12\x10\n\x08\x64\x31_index\x18\x02 \x01(\r\x12\n\n\x02\x63\x31\x18\x03 \x01(\t\x12\x10\n\x08\x63\x31_index\x18\x04 \x01(\r\x12\x0c\n\x04link\x18\x05 \x01(\t\x12\n\n\x02\x64\x32\x18\x06 \x01(\t\x12\x10\n\x08\x64\x32_index\x18\x07 \x01(\r\x12\n\n\x02\x63\x32\x18\x08 \x01(\t\x12\x10\n\x08\x63\x32_index\x18\t \x01(\r\"O\n\x10\x44\x65viceConnection\x12!\n\x04link\x18\x01 \x01(\x0b\x32\x11.infra.DeviceLinkH\x00\x12\x10\n\x06string\x18\x02 \x01(\tH\x00\x42\x06\n\x04type\";\n\x0b\x44\x65viceCount\x12\r\n\x05\x63ount\x18\x01 \x01(\r\x12\x1d\n\x06\x64\x65vice\x18\x02 \x01(\x0b\x32\r.infra.Device\"\xab\x02\n\x0c\x43ustomFabric\x12\x0c\n\x04name\x18\x01 \x01(\t\x12\x31\n\x07\x64\x65vices\x18\x02 \x03(\x0b\x32 .infra.CustomFabric.DevicesEntry\x12-\n\x05links\x18\x03 \x03(\x0b\x32\x1e.infra.CustomFabric.LinksEntry\x12,\n\x0b\x63onnections\x18\x04 \x03(\x0b\x32\x17.infra.DeviceConnection\x1a\x42\n\x0c\x44\x65vicesEntry\x12\x0b\n\x03key\x18\x01 \x01(\t\x12!\n\x05value\x18\x02 \x01(\x0b\x32\x12.infra.DeviceCount:\x02\x38\x01\x1a\x39\n\nLinksEntry\x12\x0b\n\x03key\x18\x01 \x01(\t\x12\x1a\n\x05value\x18\x02 \x01(\x0b\x32\x0b.infra.Link:\x02\x38\x01\"\xa3\x02\n\nClosFabric\x12)\n\rr ...
#      19 _globals = globals()
#
# ModuleNotFoundError: No module named 'et_def_pb2'

# %% [markdown]
# # Define a generic Switch package
#
# Create a class that models a generic switch which can be used in a fabric.

# %%
"""Generic switch device

This can be used to create devices to be used in the formation of the
infrastructure fabric.
"""

from typing import Type
import infra_pb2
import builders


class Switch(builders.PackageBuilder):
    def __init__(self, name: str, down_links: int, up_links: int = 0):
        """
        Builds a generic switch device.

        Parameters
        ----------
        name: The name of the switch device
        down_links: The number of ports used for down link adjacencies
        up_links: The number of ports used for up link adjacencies
        """
        super().__init__()
        asic = infra_pb2.Component(
            name="asic",
            count=1,
            cpu=infra_pb2.Cpu(memory=infra_pb2.MemoryType.MEM_RAM),
        )
        self._port_down = infra_pb2.Component(
            name="port-down",
            count=down_links,
            nic=infra_pb2.Nic(ethernet=infra_pb2.Ethernet()),
        )
        mac = infra_pb2.Link(
            name="mac",
            type=infra_pb2.LinkType.LINK_CUSTOM,
        )
        self._device = infra_pb2.Device(
            name=name,
            components={
                asic.name: asic,
                self._port_down.name: self._port_down,
            },
            links={
                mac.name: mac,
            },
        )
        self._create_distributed_intra_package_adjacencies(
            asic,
            mac,
            self._port_down,
        )
        self._port_up = None
        if up_links > 0:
            self._port_up = infra_pb2.Component(
                name="port-up",
                count=up_links,
                nic=infra_pb2.Nic(ethernet=infra_pb2.Ethernet()),
            )
            self._device.components[self._port_up.name].CopyFrom(self._port_up)
            self._create_distributed_intra_package_adjacencies(
                asic,
                mac,
                self._port_up,
            )

    @property
    def port_down_component(self) -> Type[infra_pb2.Component]:
        return self._port_down

    @property
    def port_up_component(self) -> Type[infra_pb2.Component]:
        return self._port_up

# %% [markdown]
# # Create the Fabric Switch packages
#
# - an instance of a rack switch with 8 down link ports and 8 up link ports
# - an instance of a pod switch with 8 down link ports

# %%
rack_switch = Switch("rack", down_links=8, up_links=8)
pod_switch = Switch("pod", down_links=8)

# %% [markdown]
# # Create the System
#
# The system should consist of the following:
#
# - 2 ZionEx packages
# - 2 rack switch packages
# - 2 pod switch packages
# - adjacencies between ZionEx packages and rack switch packages
# - adjacencies between rack switch packages and pod switch packages

# %%
# use the helper ClosFabric class which will create a fabric and
# establish connections between the device instances
fabric = builders.ClosFabric(
    host_devices=infra_pb2.DeviceCount(count=2, device=zionex._device),
    rack_devices=infra_pb2.DeviceCount(count=2, device=rack_switch),
    pod_devices=infra_pb2.DeviceCount(count=2, device=pod_switch),
)

# visualize the entire system
fabric.visualize().jupyter_display()

# %% [markdown]
# # Communication Collective Optimization Use Case
#
# Use Case:
#
# > Communication between ranks MUST use internal paths if available
# > and external paths if no internal path is available.
#
# Example:
#
# > 16 ranks over 2 ZionEx packages (1 rank per oam)
#
# - for `rank0 to rank6` (ranks are in one ZionEx host)
#   - determine the source component for rank0 and destination component for rank6
#   - evaluate algorithms in order
#   - the first algorithm `internal` yields a path `oam.0,oam-link,ep-oam-sw.0,oam-link,oam.7`
# - for `rank1 to rank10` (ranks are in different ZionEx hosts)
#   - determine the source component for rank1 and destination component for rank10
#   - evaluate algorithms in order
#   - the first algorithm `internal` yields no match
#   - move to the next algorithm `external` which yields a path `oam.1,pcie4,ep-pcie-sw.0,pcie4,cc-pcie-sw.0,pcie3,nic.1`

# %% [markdown]
# # Create a Collective Optimization
#
# The following creates a communication collective optimization for the `all to all` communication collective that consists of the following:
#
# - an `internal` algorithm for communication between oam components in the same package
# - an `external` algorithm for communication between oam components in different packages
# - a `LIFO` schedule
